# %%
# %matplotlib inline
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import webstats as w

w.basic_stats()
# Out:
# Number of invalid entries: 8
# Removing invalid entries.
# Number of invalid entries: 0

# %%
import webstats as w

w.display_nd_models()
# Out:
# Number of invalid entries: 8
# Removing invalid entries.
# Number of invalid entries: 0
# ['Error (d=1): 317389767.34',
#  'Error (d=2): 179983507.878',
#  'Error (d=3): 139350144.032',
#  'Error (d=10): 121942326.364',
#  'Error (d=100): 109452412.901']

# %%
import webstats as w

w.display_model_with_inflection_point()
# Out:
# Number of invalid entries: 8
# Removing invalid entries.
# Number of invalid entries: 0
# Error: 132950348.198

# %%
import webstats as w

w.display_model_with_future_plots()
# Out:
# Number of invalid entries: 8
# Removing invalid entries.
# Number of invalid entries: 0
# [['d', 'set a', 'set b'],
#  [1, 172343932.2053051, 145045835.13447291],
#  [2, 118867159.0685588, 61116348.809620395],
#  [3, 106135895.1261276, 33214248.905597623],
#  [10, 100330732.09964979, 21611594.263991658],
#  [100, 90796304.095876545, 18656108.805344328]]
