# %%
# %matplotlib inline
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import webstats as w

w.basic_stats()
# Out:
# Number of invalid entries: 8
# Removing invalid entries.
# Number of invalid entries: 0

# %%
import webstats as w

w.display_nd_models()
# Out:
# Number of invalid entries: 8
# Removing invalid entries.
# Number of invalid entries: 0
# ['Error (d=1): 317389767.34',
#  'Error (d=2): 179983507.878',
#  'Error (d=3): 139350144.032',
#  'Error (d=10): 121942326.364',
#  'Error (d=100): 109452412.901']

# %%
import webstats as w

w.display_model_with_inflection_point()
# Out:
# Number of invalid entries: 8
# Removing invalid entries.
# Number of invalid entries: 0
# Error: 132950348.198

# %%
import webstats as w

w.display_model_with_first_half()
# Out:
# Train n models with first half of data set
# Number of invalid entries: 8
# Removing invalid entries.
# Number of invalid entries: 0
# /Users/achiku/.virtualenvs/analysis/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# [110806407.08999814,
#  102815821.15693581,
#  101586454.41555808,
#  93236188.762864828,
#  89675011.233688235]

# %%
import webstats as w

w.display_model_with_second_half()
# Out:
# Train n models with second half of data set
# Number of invalid entries: 8
# Removing invalid entries.
# Number of invalid entries: 0
# /Users/achiku/.virtualenvs/analysis/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# /Users/achiku/.virtualenvs/analysis/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# [30013359042.1408,
#  54092723081.52652,
#  1877692644.6911483,
#  3.6997827419632572e+21,
#  1.8439980966880474e+27]

# %%
import webstats as w

w.display_cross_validateion_model()
# Out:
# Number of invalid entries: 8
# Removing invalid entries.
# Number of invalid entries: 0
# [ 90 103  65  78 113]
# Error d=1: 7644837.761952
# Error d=2: 6700570.482751
# Error d=3: 6740219.500284
# Error d=10: 6752953.265575
# Error d=53: 7420340.663006
# /Users/achiku/.virtualenvs/analysis/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# /Users/achiku/.virtualenvs/analysis/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
